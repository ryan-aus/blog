# %% [markdown]
# # Blog

# %% [markdown]
# A list of my blog posts.
#
# This site is generated by [Jupyter Book](https://jupyterbook.org/intro.html). Thanks to the contributors at [Jupyter](https://jupyter.org/) and [Executable Books](https://executablebooks.org/en/latest/index.html).

# %% [markdown]
# ## Posts
#
# ### 2022
#
# #### February
#
# - [How to waste time and overcomplicate things](260222)
